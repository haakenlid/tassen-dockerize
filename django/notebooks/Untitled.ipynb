# %%
from utils import content_factory
content_factory.random_image(size=(1000, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F1DA134D550>

# %%
content_factory.main()
# Out:
# 03:31:22 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:5 size:(3, 2)
#
# 03:31:23 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:4 size:(3, 1)
#
# 03:31:23 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:8 size:(6, 2)
#
# 03:31:24 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:8 size:(6, 2)
#
# 03:31:24 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:4 size:(4, 1)
#
# 03:31:24 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:4 size:(3, 2)
#
# 03:31:25 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:4 size:(3, 1)
#
# 03:31:25 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:2 size:(3, 1)
#
# 03:31:25 2017-02-05 [DEBUG] apps.frontpage.models    models.py:223  (autocreate)
# 	p:4 size:(4, 1)
#
# ...

# %%
content_factory.random_image(size=(1000, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500 at 0x7F1D64E28B00>
